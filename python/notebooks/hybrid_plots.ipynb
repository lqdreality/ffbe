# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
START_STAT = 300
MAX_STAT = 2000
atk, mag = np.meshgrid(np.arange(START_STAT,MAX_STAT),np.arange(START_STAT,MAX_STAT))
print(atk.shape)
print(mag.shape)
deff = [50, 100, 200, 400, 600, 800]
spr = 100
# Out:
# (1700, 1700)
# (1700, 1700)

# %%
# %matplotlib notebook

for i in range(0,len(deff)) :
    atk_mag_damage = 0.5*((atk**2/deff[i]) + (mag**2)/spr)
    plt.subplot(3,3,i+1)
    plt.imshow(atk_mag_damage, vmin=0)
    plt.title('DEF = ' + str(deff[i]))
    plt.gca().set_xticks([])
    plt.xlabel('ATK')
    plt.gca().set_yticks([])
    plt.ylabel('MAG')
    plt.colorbar()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook
plt.plot(atk, atk**2/(deff), label='attacker')
plt.plot(atk, (atk**2/(2*deff))+mag_spr_offset, label='hybrid')
plt.legend(loc=2)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
