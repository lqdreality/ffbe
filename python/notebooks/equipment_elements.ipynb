# %%
import ffbe.tools.Search
from ffbe.tools.load_pickle import load_pickle
import operator
import importlib

# %%
importlib.reload(ffbe.tools.Search)
# Out:
# <module 'ffbe.tools.Search' from '/home/chrism/ffbe/python/ffbe/tools/Search.py'>

# %%
r = ffbe.tools.Search.find_equipment(equipment, etypes=['Weapon'], has_element='Water', verbose=True)
# Out:
# Name: Brotherhood
# Type: Sword
# Trust: Yes (Tidus)
# Element(s): | Water |
# Stats:
# --------------------------------------------------
# |   HP   |   MP  |  ATK  |  MAG  |  DEF  |  SPR  |
# |  0000  |  000  |  135  |  000  |  000  |  000  |
# --------------------------------------------------
# Resistances:
# ---------------------------------------------------------------
# | Fire | Ice | Earth | Lightning | Water | Wind | Holy | Dark |
# |   00 |  00 |    00 |        00 |    00 |   00 |   00 |   00 |
# ---------------------------------------------------------------
# Status Inflict:
# -----------------------------------------------------------------------------
# | Poison | Sleep | Blind | Silence | Paralyze | Confuse | Disease | Petrify |
# |     00 |    00 |    00 |      00 |       00 |      00 |      00 |      00 |
# -----------------------------------------------------------------------------
# 2h: False
#
#
# Name: Dragon Claws
# Type: Fist
# Trust: No
# ...

# %%
r = ffbe.tools.Search.find_equipment(equipment,  stats='SPR', operators=operator.gt, comp_vals=55)
for rr in r :
    rr.print()
# Out:
# Name: Budding Maple Wand
# Type: Staff
# Trust: No
# Stats:
# --------------------------------------------------
# |   HP   |   MP  |  ATK  |  MAG  |  DEF  |  SPR  |
# |  0000  |  000  |  012  |  030  |  000  |  068  |
# --------------------------------------------------
# Resistances:
# ---------------------------------------------------------------
# | Fire | Ice | Earth | Lightning | Water | Wind | Holy | Dark |
# |   00 |  00 |    00 |        00 |    00 |   00 |   00 |   00 |
# ---------------------------------------------------------------
# Status Inflict:
# -----------------------------------------------------------------------------
# | Poison | Sleep | Blind | Silence | Paralyze | Confuse | Disease | Petrify |
# |     00 |    00 |    00 |      00 |       00 |      00 |      00 |      00 |
# -----------------------------------------------------------------------------
# 2h: False
# Name: Holy Wand
# Type: Staff
# Trust: No
# Element(s): | Light |
# Stats:
# ...

# %%
rr = ffbe.tools.Search.find_equipment(my_equipment, etypes=['Great Sword'], verbose=True)
# Out:
# Name: Beastlord
# Type: Great Sword
# Trust: Yes (A2)
# Stats:
# --------------------------------------------------
# |   HP   |   MP  |  ATK  |  MAG  |  DEF  |  SPR  |
# |  0000  |  000  |  125  |  000  |  000  |  000  |
# --------------------------------------------------
# Resistances:
# ---------------------------------------------------------------
# | Fire | Ice | Earth | Lightning | Water | Wind | Holy | Dark |
# |   00 |  00 |    00 |        00 |    00 |   00 |   00 |   00 |
# ---------------------------------------------------------------
# Status Inflict:
# -----------------------------------------------------------------------------
# | Poison | Sleep | Blind | Silence | Paralyze | Confuse | Disease | Petrify |
# |     00 |    00 |    00 |      00 |       00 |      00 |      00 |      00 |
# -----------------------------------------------------------------------------
# 2h: False
#
#
# Name: Rune Blade
# Type: Great Sword
# Trust: No
# Element(s): | Light |
# Stats:
# ...
